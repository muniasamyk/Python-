# %%
import matplotlib.pyplot as plt
a = [1,6]
b =[2,5]
plt.plot(a,b)
plt.title("Product label")
plt.show()

# %%
import numpy as np
A = np.array([1,3,5,7,9])
B = np.array([5,10,50,20,25])
plt.plot(A,B)
plt.title("Array char")
plt.show()

# %%
Ax = np.array([1,3,5,7,9])
By = np.array([5,10,50,60,25])
plt.plot(Ax,By, color="r",marker="s", )
plt.title("Array char")
plt.show()

# %%
Ax = np.array([1,3,5,7,9])
By = np.array([5,10,50,60,25])
plt.plot(Ax,By, color="b",marker="s", ms="10", mec="g" , mfc="r" )
plt.title("Array char")
plt.show()

# %%
Ax = np.array([1,3,5,7,9])
By = np.array([5,6,7,9,11])
plt.bar(Ax,By, color="g" )
plt.title("Array char", fontdic = font1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14016/1925675029.py in <module>
#       2 By = np.array([5,6,7,9,11])
#       3 plt.bar(Ax,By, color="g" )
# ----> 4 plt.title("Array char", fontdic = font1)
#       5 plt.show()
#
# NameError: name 'font1' is not defined

# %%
Ax = np.array([1,3,5,7,9])
By = np.array([5,10,50,60,25])
plt.plot(Ax,By, color="r",marker="s", )
plt.title("Array char")
plt.show()
